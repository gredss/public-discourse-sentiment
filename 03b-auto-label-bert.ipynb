# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/cleaned-dpr/cleaned_dpr.csv")

# %%
model_name = "mdhugol/indonesia-bert-sentiment-classification"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

sentiment_pipeline = pipeline("text-classification", model=model, tokenizer=tokenizer)
# Out:
# Device set to use cuda:0

# %%
def label_comment(text):
    try:
        result = sentiment_pipeline(str(text)[:512])[0]  # ensure string, truncate if >512
        return result['label']
    except:
        return "Unknown"

# Inference on both raw and clean text
df["label_raw"] = df["Comment"].apply(label_comment)          # raw comment
df["label_clean"] = df["clean_comment"].apply(label_comment)  # cleaned comment
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
print("Raw Comment Distribution:")
df["label_raw"].value_counts(normalize=True)
# Out:
# Raw Comment Distribution:
# label_raw
# LABEL_2    0.703610
# LABEL_0    0.180241
# LABEL_1    0.116150
# Name: proportion, dtype: float64

# %%
print("\nClean Comment Distribution:")
df["label_clean"].value_counts(normalize=True)
# Out:
# Clean Comment Distribution:
# label_clean
# LABEL_2    0.704904
# LABEL_0    0.180672
# LABEL_1    0.114424
# Name: proportion, dtype: float64

# %%
# compare agreement between raw and clean labels
df["agree"] = df["label_raw"] == df["label_clean"]

agreement_rate = df["agree"].mean() * 100
print(f"Agreement rate between raw and clean labels: {agreement_rate:.2f}%")

# first 20 mismatches
mismatches = df[df["agree"] == False][["Comment", "clean_comment", "label_raw", "label_clean"]]
print("\nFirst 20 mismatches:\n")
mismatches.head(20)
# Out:
# Agreement rate between raw and clean labels: 99.77%
#
# First 20 mismatches:
#                                                 Comment  \
# 119                       ​@@semestaraya562oooh gitu ya
# 207                        @@RadioSantuyID Siap gaspool
# 211   @@RadioSantuyID untuk mereka yg menempatkan di...
# 312           ​@@RadioSantuyIDhayu atuh Wang kompak Ken
# 469                           ​@@RadioSantuyIDia mang😮😅
# 1186  iya emang cmn rakyat yg b​isa kang...kedaulata...
# 1329  Maklum,di senayan taman bermain para bocil2🤣​@...
# 1526                      ​@@RadioSantuyIDtah kitu kang
# 1582                   ​@@RadioSantuyIDemang omon omon😂
# 1688                        ​@@hhhhhh4808ambyar gak tuh
# 1768  ​@@anisazizah5464 pilih yg mendingan dari semu...
# 1802  ​@@RadioSantuyIDwkwk\nDi rosting sama KDM keba...
# 1983  ​@@RadioSantuyIDhaturnuhun..salam saduluran  a...
# 2019            @@RadioSantuyID YES....... SIAP LAKUKAN
# 2024                         ​@@RadioSantuyIDsedih mang
# 2176  ​@@RadioSantuyIDbisa ga zih dpr yg lulus coblo...
# 2228                          ​@@RadioSantuyIDsumuhun 🤭
# 2284  ​@@ervantputrarahman4574jiahahaha gk mungkin,k...
# 2337                   ​@@RadioSantuyIDBiar tau Bang...
# 2402        @@RadioSantuyID DPR BUBAR INDONESIA MERDEKA
#
#                                           clean_comment label_raw label_clean
# 119                                          ​@ gitu ya   LABEL_0     LABEL_2
# 207                                      @ siap gaspool   LABEL_1     LABEL_0
# 211   @ untuk mereka yg menempatkan diri sebagai opo...   LABEL_0     LABEL_2
# 312                             ​@ atuh wang kompak ken   LABEL_1     LABEL_0
# 469                                           ​@ mang😮😅   LABEL_1     LABEL_2
# 1186  iya emang cmn rakyat yg b​isa kang...kedaulata...   LABEL_1     LABEL_2
# 1329     maklum,di senayan taman bermain para bocil2🤣​@   LABEL_1     LABEL_2
# 1526                                       ​@ kitu kang   LABEL_1     LABEL_2
# 1582                                      ​@ omon omon😂   LABEL_1     LABEL_2
# 1688                                         ​@ gak tuh   LABEL_0     LABEL_2
# 1768                ​@ pilih yg mendingan dari semuanya   LABEL_1     LABEL_2
# 1802    ​@ di rosting sama kdm kebakaran bulu jemari. 😂   LABEL_1     LABEL_2
# 1983           ​@..salam saduluran abdi cilacao..jateng   LABEL_1     LABEL_0
# 2019                          @ yes....... siap lakukan   LABEL_1     LABEL_0
# 2024                                            ​@ mang   LABEL_0     LABEL_2
# 2176  ​@ ga zih dpr yg lulus coblos trus di uji peng...   LABEL_1     LABEL_2
# 2228                                               ​@ 🤭   LABEL_1     LABEL_2
# 2284               ​@ gk mungkin,kpps ada gajinya boss😂   LABEL_1     LABEL_2
# 2337                                     ​@ tau bang...   LABEL_1     LABEL_2
# 2402                      @ dpr bubar indonesia merdeka   LABEL_1     LABEL_2

# %%
df = df[["Comment", "label_raw"]]
df.rename(columns={"label_raw":"auto_label"}, inplace=True)

# %%
label_map = {"LABEL_0": "negative", "LABEL_1": "neutral", "LABEL_2": "positive"}
df["auto_label"] = df["auto_label"].map(label_map)
df.head(5)
# Out:
#                                              Comment auto_label
# 0                      Samber geledek DPR biar angus   positive
# 1  Kalau begini jadi kangen gaya kepemimpinan pak...   negative
# 2  Gak ngertiin perasaan masyarakat.yang sekarang...   positive
# 3  BUBARKAN MRP DPR. ALOKASI GAJI MEREKA BUAT RAK...   positive
# 4                  Bubarin DPR biar rakyat sejahtera   positive

# %%
df.to_csv("autolabeled_bert.csv", index=False)
