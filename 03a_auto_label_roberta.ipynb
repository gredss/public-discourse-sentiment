# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import pandas as pd

# %%
df = pd.read_csv("cleaned_dpr.csv")

# %%
model_name = "w11wo/indonesian-roberta-base-sentiment-classifier"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

sentiment_pipeline = pipeline("text-classification", model=model, tokenizer=tokenizer)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/328 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
def label_comment(text):
    try:
        result = sentiment_pipeline(str(text)[:512])[0]  # ensure string, truncate if >512
        return result['label']
    except:
        return "Unknown"

# Inference on both raw and clean text
df["label_raw"] = df["Comment"].apply(label_comment)          # raw comment
df["label_clean"] = df["clean_comment"].apply(label_comment)  # cleaned comment
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
print("Raw Comment Distribution:")
df["label_raw"].value_counts(normalize=True)
# Out:
# Raw Comment Distribution:
# label_raw
# negative    0.681942
# positive    0.207421
# neutral     0.110445
# Unknown     0.000192
# Name: proportion, dtype: float64

# %%
print("\nClean Comment Distribution:")
df["label_clean"].value_counts(normalize=True)
# Out:
# Clean Comment Distribution:
# label_clean
# negative    0.648675
# positive    0.204209
# neutral     0.146925
# Unknown     0.000192
# Name: proportion, dtype: float64

# %%
# compare agreement between raw and clean labels
df["agree"] = df["label_raw"] == df["label_clean"]

agreement_rate = df["agree"].mean() * 100
print(f"Agreement rate between raw and clean labels: {agreement_rate:.2f}%")

# first 20 mismatches
mismatches = df[df["agree"] == False][["Comment", "clean_comment", "label_raw", "label_clean"]]
print("\nFirst 20 mismatches:\n")
mismatches.head(20)
# Out:
# Agreement rate between raw and clean labels: 87.96%
#
# First 20 mismatches:
#                                                Comment  \
# 4                    Bubarin DPR biar rakyat sejahtera
# 8              Wakil Rakyat Seharusnya Merakyat!!!....
# 25   Emang bangsa* DPR berjoget diatas penderitaan ...
# 29   Dari sabang sampe marauke siap dukung bubarkan...
# 34                                      Geleh aink mah
# 45                                         Hidup KDM❤❤
# 73   Gak ada yg bisa bubarin DPR bang....kekuasaan ...
# 82                        Dewan BEBAN BESAR utk RAKYAT
# 85                               Dewan Perampok Rakyat
# 96   ALHAMDULILLAH\nSUDAH 3 KALI PEMILU GA PERNAH I...
# 105  Indonesia kalo gak ad DPR dan MPR rakyat indon...
# 111  Setuju, tiap darah tgl 25 serentak bubarkan dpr..
# 136  Say paling enek sama artis yg jadi DPR yg joge...
# 137                                         Boikot DPR
# 147  Kenapa gusdur di lengserkan ? Karena pernah in...
# 148                                                Nah
# 153                        Indonesia merdeka tanpa DPR
# 154                                Bisa dicoba gak sih
# 155  Kalau DPR dibubarkan tidak akan ada Korupsi da...
# 157  Ciga NU rujit Kitu mas Gibran ninggali ondel- ...
#
#                                          clean_comment label_raw label_clean
# 4                    bubarin dpr biar rakyat sejahtera  negative     neutral
# 8              wakil rakyat seharusnya merakyat!!!....  negative    positive
# 25   emang bangsa* dpr berjoget diatas penderitaan ...  negative     neutral
# 29   dari sabang sampe marauke siap dukung bubarkan...  negative     neutral
# 34                                      geleh aink mah  positive    negative
# 45                                         hidup kdm❤❤  positive     neutral
# 73   gak ada yg bisa bubarin dpr bang....kekuasaan ...  positive     neutral
# 82                        dewan beban besar utk rakyat   neutral    positive
# 85                               dewan perampok rakyat  negative     neutral
# 96   alhamdulillah sudah 3 kali pemilu ga pernah ik...  negative    positive
# 105  indonesia kalo gak ad dpr dan mpr rakyat indon...  negative    positive
# 111  setuju, tiap darah tgl 25 serentak bubarkan dpr..  negative     neutral
# 136  say paling enek sama artis yg jadi dpr yg joge...  negative    positive
# 137                                         boikot dpr  positive     neutral
# 147  kenapa gusdur di lengserkan ? karena pernah in...  negative     neutral
# 148                                                nah  positive    negative
# 153                        indonesia merdeka tanpa dpr  positive     neutral
# 154                                bisa dicoba gak sih  positive    negative
# 155  kalau dpr dibubarkan tidak akan ada korupsi da...  negative     neutral
# 157  ciga nu rujit kitu mas gibran ninggali ondel- ...  positive     neutral

# %%
df.to_csv("autolabeled_roberta.csv", index=False)
